# %%
def greet():
    print("Hello Satyam!")

greet()
# Out:
# Hello Satyam!

# %%
def add(a, b):
    print(a + b)
add(5,7)
# Out:
# 12

# %%
def multiply(a, b):
    return a * b

result = multiply(4, 6)
print(result)
# Out:
# 24

# %%
def welcome(name="Guest"):
    print("Welcome", name)

welcome()         
welcome("Satyam")
# Out:
# Welcome Guest
# Welcome Satyam

# %%
def calc(a, b):
    return a + b, a * b

sum_val, mul_val = calc(3, 5)
print(sum_val, mul_val)
# Out:
# 8 15

# %%
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
fruits = ["apple", "banana", "mango"]
for x in fruits:
    print(x)
# Out:
# apple
# banana
# mango

# %%
i = 1
while i <= 5:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1, 10):
    if i == 5:
        break
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
fruits = ["apple","banana","mango"]
print(fruits)
# Out:
# ['apple', 'banana', 'mango']

# %%
type(fruits)
# Out:
# list

# %%
fruits.append('grapes')

# %%
print(fruits)
# Out:
# ['apple', 'banana', 'mango', 'grapes']

# %%
fruits[0:3]
# Out:
# ['apple', 'banana', 'mango']

# %%
fruits.remove('mango')

# %%
print(fruits)
# Out:
# ['apple', 'banana', 'grapes']

# %%
my_tuple = (10, "apple", 3.14)
print(my_tuple)
# Out:
# (10, 'apple', 3.14)

# %%
student = {
    "name": "Satyam",
    "age": 27,
    "course": "B.Ed"
}

print(student)
# Out:
# {'name': 'Satyam', 'age': 27, 'course': 'B.Ed'}

# %%
print(student["name"])
# Out:
# Satyam

# %%
student["grade"] = "A"
print(student)
# Out:
# {'name': 'Satyam', 'age': 27, 'course': 'B.Ed', 'grade': 'A'}

# %%
my_number = 33

# %%
if my_number % 2 == 0:
    print('The given number {} is even.'.format(my_number))
else:
    print('The given number {} is odd.'.format(my_number))
# Out:
# The given number 33 is odd.

# %%
my_number = 32

# %%
if my_number % 2 == 0:
    print('The given number {} is even.'.format(my_number))
else:
    print('The given number {} is odd.'.format(my_number))
# Out:
# The given number 32 is even.

# %%
def sum(a,b):
    return(a+b)
sum(5,6)
# Out:
# 11

# %%
[1,23,4,5]
33

# %%
sum(6,7)
# Out:
# 13

# %%
my_number = [1,23,4,5]
total = 0

for x in my_number:
   total = x+total

# %%
print(total)
# Out:
# 33

# %%
i= 0
total = 0
while i < len(my_number):
    total = total+ my_number[i]
    i= i+1

# %%
my_list = [20,10,12,11]
toatal = 0

for x in my_list:
    total = x+total

# %%
print(total)
# Out:
# 86

# %%
my_integer = [3,9,6,4,2,5,11,12,14,19]
total = 0

for x in my_integer:
    total = x+ abc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[161], line 5
#       2 total = 0
#       4 for x in my_integer:
# ----> 5     total = x+ abc
#
# NameError: name 'abc' is not defined

# %%
print(total)
# Out:
# 85

# %%
def add_items(items):
    total=0
    for x in items:
        total = x+ total 
    return total

# %%
items = [3,6,7,8]

# %%
add_items(items)
# Out:
# 3

# %%
add_items(my_integer)
# Out:
# 85

# %%
add_items(my_list)
# Out:
# 53

# %%
add_items(my_number)
# Out:
# 33

# %%
add_items([3,4,5,9])
# Out:
# 21
